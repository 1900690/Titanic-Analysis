# %% [markdown]
# <a href="https://colab.research.google.com/github/1900690/Titanic-Analysis/blob/main/employment_questionnaire.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [参考：タイタニックの生存予測 チュートリアル ～初級編～](https://signate.jp/competitions/102/tutorials/23)

# %%
#@title csvファイルをアップロード（またはサンプルで分析）
from google.colab import files
import os
from os.path import exists
import pandas as pd

サンプルを使用する = False # @param {type:"boolean"}

if サンプルを使用する == True:
    if os.path.exists("employment-questionnaire-train.csv"):
        os.remove("employment-questionnaire-train.csv")
    # !wget -q https://github.com/1900690/Titanic-Analysis/releases/download/sample-data/employment-questionnaire-train.csv
    os.rename("employment-questionnaire-train.csv","train.csv")
else:
  uploaded_file = files.upload()
  uploaded_file_name = next(iter(uploaded_file))
  os.rename(uploaded_file_name,"train.csv")

train = pd.read_csv("train.csv",index_col=0) # 学習用データ
train.head()
# Out:
#      <input type="file" id="files-bfdff178-78bd-4947-8b6e-1eb12341563f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bfdff178-78bd-4947-8b6e-1eb12341563f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#@title 基本的な情報を表示
train.describe()
# Out:
#               q1         q2         q3         q4         q5         q6  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    3.900000   2.200000   2.500000   3.800000   1.800000   2.600000
# std     0.994429   0.918937   1.649916   1.316561   1.229273   1.264911
# min     2.000000   1.000000   1.000000   2.000000   1.000000   1.000000
# 25%     3.250000   2.000000   1.000000   2.500000   1.000000   2.000000
# 50%     4.000000   2.000000   2.000000   4.000000   1.500000   2.500000
# 75%     4.750000   2.750000   4.000000   5.000000   2.000000   3.000000
# max     5.000000   4.000000   5.000000   5.000000   5.000000   5.000000
#
#          regular  parttime  agriculture-and-welfare-cooperation  \
# count  10.000000  10.00000                            10.000000
# mean    0.800000   4.10000                             0.500000
# std     0.632456   2.13177                             1.581139
# ...

# %% [markdown]
# *   count: 欠損値NaNではない要素の個数
# *   unique: ユニークな要素の数（重複を除いた件数）
# *   top: 最頻値（mode）
# *   freq: 最頻値の頻度（出現回数）
# *   mean: 算術平均
# *   std: 標準偏差
# *   min: 最小値
# *   max: 最大値
# *   50%: 中央値（median）
# *   25%, 75%: 1/4分位数、3/4分位数

# %%
#@title 記入した列に対する相関係数を調べる
相関係数を調べる列名="regular"#@param {type:"string"}
pd.get_dummies(train).corrwith(train[相関係数を調べる列名])
# Out:
# q1                                    -0.035333
# q2                                    -0.305888
# q3                                    -0.212959
# q4                                     0.080064
# q5                                     0.085749
# q6                                     0.027778
# regular                                1.000000
# parttime                              -0.477986
# agriculture-and-welfare-cooperation   -0.444444
# one-shoot-job                         -0.152145
# foreign-technical-intern              -0.145479
# dtype: float64

# %% [markdown]
# 相関係数が 1 に近いと正の相関、-1 に近いと負の相関が強く、0に近いと相関が弱いことを表す。
